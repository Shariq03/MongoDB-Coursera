# %%
import pymongo
from pprint import pprint

# %%
client = pymongo.MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
client.citibike.collection_names()
# Out:
# ['trips']

# %%
trips = client.citibike.trips

# %%
pprint (trips.find_one())
# Out:
# {'_id': ObjectId('572bb8222b288919b68adfa5'),
#  'bikeid': 22820,
#  'birth year': '',
#  'end station id': 268,
#  'end station location': {'coordinates': [-73.99973337, 40.71910537],
#                           'type': 'Point'},
#  'end station name': 'Howard St & Centre St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 1, 17, 19, 38),
#  'stop time': datetime.datetime(2016, 1, 1, 17, 29, 42),
#  'tripduration': None,
#  'usertype': 'Customer'}

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [
    {"$match": {"start station id": 279}},
    {"$group": {
            "_id": {"end station id": "$end station id",
#                     "start station id": "$start station id"
            },
            "agg_count": {"$sum": 1}
        }
    },
    {"$sort": {"agg_count": -1}}
]

# %%
# print the results
for trip in trips.aggregate(pipeline):
    pprint(trip)
# Out:
# {'_id': {'end station id': 279}, 'agg_count': 137}
# {'_id': {'end station id': 316}, 'agg_count': 112}
# {'_id': {'end station id': 259}, 'agg_count': 104}
# {'_id': {'end station id': 387}, 'agg_count': 99}
# {'_id': {'end station id': 224}, 'agg_count': 86}
# {'_id': {'end station id': 306}, 'agg_count': 83}
# {'_id': {'end station id': 268}, 'agg_count': 80}
# {'_id': {'end station id': 260}, 'agg_count': 75}
# {'_id': {'end station id': 308}, 'agg_count': 73}
# {'_id': {'end station id': 360}, 'agg_count': 71}
# {'_id': {'end station id': 3002}, 'agg_count': 63}
# {'_id': {'end station id': 361}, 'agg_count': 57}
# {'_id': {'end station id': 337}, 'agg_count': 56}
# {'_id': {'end station id': 487}, 'agg_count': 55}
# {'_id': {'end station id': 2009}, 'agg_count': 54}
# {'_id': {'end station id': 401}, 'agg_count': 53}
# {'_id': {'end station id': 307}, 'agg_count': 52}
# {'_id': {'end station id': 376}, 'agg_count': 51}
# {'_id': {'end station id': 502}, 'agg_count': 51}
# {'_id': {'end station id': 304}, 'agg_count': 50}
# {'_id': {'end station id': 501}, 'agg_count': 47}
# {'_id': {'end station id': 332}, 'agg_count': 46}
# {'_id': {'end station id': 2010}, 'agg_count': 43}
# {'_id': {'end station id': 232}, 'agg_count': 43}
# {'_id': {'end station id': 174}, 'agg_count': 41}
# {'_id': {'end station id': 291}, 'agg_count': 39}
# {'_id': {'end station id': 408}, 'agg_count': 38}
# {'_id': {'end station id': 195}, 'agg_count': 37}
# {'_id': {'end station id': 329}, 'agg_count': 37}
# {'_id': {'end station id': 511}, 'agg_count': 36}
# {'_id': {'end station id': 415}, 'agg_count': 34}
# {'_id': {'end station id': 319}, 'agg_count': 34}
# {'_id': {'end station id': 264}, 'agg_count': 33}
# {'_id': {'end station id': 350}, 'agg_count': 33}
# {'_id': {'end station id': 312}, 'agg_count': 32}
# {'_id': {'end station id': 531}, 'agg_count': 32}
# {'_id': {'end station id': 147}, 'agg_count': 31}
# {'_id': {'end station id': 386}, 'agg_count': 30}
# {'_id': {'end station id': 327}, 'agg_count': 30}
# {'_id': {'end station id': 151}, 'agg_count': 30}
# {'_id': {'end station id': 341}, 'agg_count': 29}
# {'_id': {'end station id': 426}, 'agg_count': 29}
# {'_id': {'end station id': 445}, 'agg_count': 27}
# {'_id': {'end station id': 152}, 'agg_count': 26}
# {'_id': {'end station id': 150}, 'agg_count': 26}
# {'_id': {'end station id': 320}, 'agg_count': 26}
# {'_id': {'end station id': 410}, 'agg_count': 25}
# {'_id': {'end station id': 394}, 'agg_count': 25}
# {'_id': {'end station id': 428}, 'agg_count': 24}
# {'_id': {'end station id': 321}, 'agg_count': 24}
# {'_id': {'end station id': 534}, 'agg_count': 23}
# {'_id': {'end station id': 257}, 'agg_count': 23}
# {'_id': {'end station id': 476}, 'agg_count': 23}
# {'_id': {'end station id': 433}, 'agg_count': 23}
# {'_id': {'end station id': 249}, 'agg_count': 23}
# {'_id': {'end station id': 351}, 'agg_count': 23}
# {'_id': {'end station id': 417}, 'agg_count': 22}
# {'_id': {'end station id': 263}, 'agg_count': 22}
# {'_id': {'end station id': 485}, 'agg_count': 22}
# {'_id': {'end station id': 315}, 'agg_count': 22}
# {'_id': {'end station id': 276}, 'agg_count': 22}
# {'_id': {'end station id': 504}, 'agg_count': 21}
# {'_id': {'end station id': 545}, 'agg_count': 21}
# {'_id': {'end station id': 427}, 'agg_count': 21}
# {'_id': {'end station id': 295}, 'agg_count': 21}
# {'_id': {'end station id': 217}, 'agg_count': 20}
# {'_id': {'end station id': 392}, 'agg_count': 20}
# {'_id': {'end station id': 296}, 'agg_count': 20}
# {'_id': {'end station id': 432}, 'agg_count': 20}
# {'_id': {'end station id': 455}, 'agg_count': 20}
# {'_id': {'end station id': 532}, 'agg_count': 19}
# {'_id': {'end station id': 301}, 'agg_count': 19}
# {'_id': {'end station id': 2008}, 'agg_count': 19}
# {'_id': {'end station id': 461}, 'agg_count': 19}
# {'_id': {'end station id': 356}, 'agg_count': 19}
# {'_id': {'end station id': 507}, 'agg_count': 19}
# {'_id': {'end station id': 355}, 'agg_count': 18}
# {'_id': {'end station id': 524}, 'agg_count': 18}
# {'_id': {'end station id': 340}, 'agg_count': 18}
# {'_id': {'end station id': 3119}, 'agg_count': 18}
# {'_id': {'end station id': 411}, 'agg_count': 18}
# {'_id': {'end station id': 303}, 'agg_count': 18}
# {'_id': {'end station id': 519}, 'agg_count': 17}
# {'_id': {'end station id': 317}, 'agg_count': 17}
# {'_id': {'end station id': 339}, 'agg_count': 17}
# {'_id': {'end station id': 79}, 'agg_count': 16}
# {'_id': {'end station id': 297}, 'agg_count': 16}
# {'_id': {'end station id': 82}, 'agg_count': 16}
# {'_id': {'end station id': 309}, 'agg_count': 16}
# {'_id': {'end station id': 516}, 'agg_count': 15}
# {'_id': {'end station id': 460}, 'agg_count': 15}
# {'_id': {'end station id': 229}, 'agg_count': 15}
# {'_id': {'end station id': 293}, 'agg_count': 15}
# {'_id': {'end station id': 393}, 'agg_count': 15}
# {'_id': {'end station id': 363}, 'agg_count': 15}
# {'_id': {'end station id': 331}, 'agg_count': 15}
# {'_id': {'end station id': 2004}, 'agg_count': 14}
# {'_id': {'end station id': 330}, 'agg_count': 14}
# {'_id': {'end station id': 285}, 'agg_count': 13}
# {'_id': {'end station id': 349}, 'agg_count': 13}
# {'_id': {'end station id': 438}, 'agg_count': 13}
# {'_id': {'end station id': 265}, 'agg_count': 12}
# {'_id': {'end station id': 473}, 'agg_count': 12}
# {'_id': {'end station id': 302}, 'agg_count': 12}
# {'_id': {'end station id': 146}, 'agg_count': 12}
# {'_id': {'end station id': 322}, 'agg_count': 12}
# {'_id': {'end station id': 472}, 'agg_count': 12}
# {'_id': {'end station id': 518}, 'agg_count': 12}
# {'_id': {'end station id': 250}, 'agg_count': 12}
# {'_id': {'end station id': 382}, 'agg_count': 11}
# {'_id': {'end station id': 2012}, 'agg_count': 11}
# {'_id': {'end station id': 375}, 'agg_count': 11}
# {'_id': {'end station id': 412}, 'agg_count': 11}
# {'_id': {'end station id': 400}, 'agg_count': 10}
# {'_id': {'end station id': 527}, 'agg_count': 10}
# {'_id': {'end station id': 237}, 'agg_count': 10}
# {'_id': {'end station id': 2003}, 'agg_count': 10}
# {'_id': {'end station id': 497}, 'agg_count': 10}
# {'_id': {'end station id': 347}, 'agg_count': 9}
# {'_id': {'end station id': 348}, 'agg_count': 9}
# {'_id': {'end station id': 251}, 'agg_count': 8}
# {'_id': {'end station id': 236}, 'agg_count': 8}
# {'_id': {'end station id': 161}, 'agg_count': 8}
# {'_id': {'end station id': 323}, 'agg_count': 8}
# {'_id': {'end station id': 128}, 'agg_count': 8}
# {'_id': {'end station id': 280}, 'agg_count': 8}
# {'_id': {'end station id': 326}, 'agg_count': 8}
# {'_id': {'end station id': 475}, 'agg_count': 8}
# {'_id': {'end station id': 377}, 'agg_count': 8}
# {'_id': {'end station id': 459}, 'agg_count': 8}
# {'_id': {'end station id': 3104}, 'agg_count': 8}
# {'_id': {'end station id': 493}, 'agg_count': 7}
# {'_id': {'end station id': 328}, 'agg_count': 7}
# {'_id': {'end station id': 167}, 'agg_count': 7}
# {'_id': {'end station id': 278}, 'agg_count': 7}
# {'_id': {'end station id': 311}, 'agg_count': 7}
# {'_id': {'end station id': 405}, 'agg_count': 7}
# {'_id': {'end station id': 440}, 'agg_count': 6}
# {'_id': {'end station id': 414}, 'agg_count': 6}
# {'_id': {'end station id': 439}, 'agg_count': 6}
# {'_id': {'end station id': 407}, 'agg_count': 6}
# {'_id': {'end station id': 225}, 'agg_count': 6}
# {'_id': {'end station id': 83}, 'agg_count': 6}
# {'_id': {'end station id': 430}, 'agg_count': 6}
# {'_id': {'end station id': 483}, 'agg_count': 5}
# {'_id': {'end station id': 3074}, 'agg_count': 5}
# {'_id': {'end station id': 346}, 'agg_count': 5}
# {'_id': {'end station id': 153}, 'agg_count': 5}
# {'_id': {'end station id': 168}, 'agg_count': 5}
# {'_id': {'end station id': 539}, 'agg_count': 5}
# {'_id': {'end station id': 491}, 'agg_count': 5}
# {'_id': {'end station id': 160}, 'agg_count': 5}
# {'_id': {'end station id': 247}, 'agg_count': 5}
# {'_id': {'end station id': 266}, 'agg_count': 5}
# {'_id': {'end station id': 402}, 'agg_count': 5}
# {'_id': {'end station id': 368}, 'agg_count': 5}
# {'_id': {'end station id': 468}, 'agg_count': 5}
# {'_id': {'end station id': 253}, 'agg_count': 5}
# {'_id': {'end station id': 467}, 'agg_count': 4}
# {'_id': {'end station id': 536}, 'agg_count': 4}
# {'_id': {'end station id': 383}, 'agg_count': 4}
# {'_id': {'end station id': 380}, 'agg_count': 4}
# {'_id': {'end station id': 3058}, 'agg_count': 4}
# {'_id': {'end station id': 528}, 'agg_count': 4}
# {'_id': {'end station id': 358}, 'agg_count': 4}
# {'_id': {'end station id': 525}, 'agg_count': 4}
# {'_id': {'end station id': 469}, 'agg_count': 4}
# {'_id': {'end station id': 2000}, 'agg_count': 4}
# {'_id': {'end station id': 462}, 'agg_count': 4}
# {'_id': {'end station id': 406}, 'agg_count': 4}
# {'_id': {'end station id': 540}, 'agg_count': 4}
# {'_id': {'end station id': 127}, 'agg_count': 4}
# {'_id': {'end station id': 391}, 'agg_count': 3}
# {'_id': {'end station id': 494}, 'agg_count': 3}
# {'_id': {'end station id': 3055}, 'agg_count': 3}
# {'_id': {'end station id': 248}, 'agg_count': 3}
# {'_id': {'end station id': 116}, 'agg_count': 3}
# {'_id': {'end station id': 216}, 'agg_count': 3}
# {'_id': {'end station id': 453}, 'agg_count': 3}
# {'_id': {'end station id': 310}, 'agg_count': 3}
# {'_id': {'end station id': 454}, 'agg_count': 3}
# {'_id': {'end station id': 3105}, 'agg_count': 3}
# {'_id': {'end station id': 403}, 'agg_count': 3}
# {'_id': {'end station id': 238}, 'agg_count': 3}
# {'_id': {'end station id': 481}, 'agg_count': 3}
# {'_id': {'end station id': 521}, 'agg_count': 3}
# {'_id': {'end station id': 284}, 'agg_count': 3}
# {'_id': {'end station id': 444}, 'agg_count': 3}
# {'_id': {'end station id': 3093}, 'agg_count': 3}
# {'_id': {'end station id': 435}, 'agg_count': 3}
# {'_id': {'end station id': 523}, 'agg_count': 3}
# {'_id': {'end station id': 2022}, 'agg_count': 3}
# {'_id': {'end station id': 336}, 'agg_count': 3}
# {'_id': {'end station id': 3142}, 'agg_count': 3}
# {'_id': {'end station id': 486}, 'agg_count': 3}
# {'_id': {'end station id': 384}, 'agg_count': 2}
# {'_id': {'end station id': 465}, 'agg_count': 2}
# {'_id': {'end station id': 474}, 'agg_count': 2}
# {'_id': {'end station id': 503}, 'agg_count': 2}
# {'_id': {'end station id': 369}, 'agg_count': 2}
# {'_id': {'end station id': 3135}, 'agg_count': 2}
# {'_id': {'end station id': 3147}, 'agg_count': 2}
# {'_id': {'end station id': 517}, 'agg_count': 2}
# {'_id': {'end station id': 496}, 'agg_count': 2}
# {'_id': {'end station id': 274}, 'agg_count': 2}
# {'_id': {'end station id': 3173}, 'agg_count': 2}
# {'_id': {'end station id': 537}, 'agg_count': 2}
# {'_id': {'end station id': 3242}, 'agg_count': 2}
# {'_id': {'end station id': 3140}, 'agg_count': 2}
# {'_id': {'end station id': 482}, 'agg_count': 2}
# {'_id': {'end station id': 526}, 'agg_count': 2}
# {'_id': {'end station id': 389}, 'agg_count': 2}
# {'_id': {'end station id': 508}, 'agg_count': 2}
# {'_id': {'end station id': 252}, 'agg_count': 2}
# {'_id': {'end station id': 3103}, 'agg_count': 2}
# {'_id': {'end station id': 3159}, 'agg_count': 2}
# {'_id': {'end station id': 470}, 'agg_count': 2}
# {'_id': {'end station id': 3148}, 'agg_count': 2}
# {'_id': {'end station id': 357}, 'agg_count': 2}
# {'_id': {'end station id': 3016}, 'agg_count': 2}
# {'_id': {'end station id': 2002}, 'agg_count': 2}
# {'_id': {'end station id': 546}, 'agg_count': 2}
# {'_id': {'end station id': 212}, 'agg_count': 2}
# {'_id': {'end station id': 3064}, 'agg_count': 2}
# {'_id': {'end station id': 416}, 'agg_count': 2}
# {'_id': {'end station id': 514}, 'agg_count': 2}
# {'_id': {'end station id': 3222}, 'agg_count': 1}
# {'_id': {'end station id': 458}, 'agg_count': 1}
# {'_id': {'end station id': 262}, 'agg_count': 1}
# {'_id': {'end station id': 480}, 'agg_count': 1}
# {'_id': {'end station id': 3141}, 'agg_count': 1}
# {'_id': {'end station id': 3113}, 'agg_count': 1}
# {'_id': {'end station id': 456}, 'agg_count': 1}
# {'_id': {'end station id': 245}, 'agg_count': 1}
# {'_id': {'end station id': 3171}, 'agg_count': 1}
# {'_id': {'end station id': 3144}, 'agg_count': 1}
# {'_id': {'end station id': 3088}, 'agg_count': 1}
# {'_id': {'end station id': 3244}, 'agg_count': 1}
# {'_id': {'end station id': 3052}, 'agg_count': 1}
# {'_id': {'end station id': 254}, 'agg_count': 1}
# {'_id': {'end station id': 449}, 'agg_count': 1}
# {'_id': {'end station id': 509}, 'agg_count': 1}
# {'_id': {'end station id': 2006}, 'agg_count': 1}
# {'_id': {'end station id': 3158}, 'agg_count': 1}
# {'_id': {'end station id': 3223}, 'agg_count': 1}
# {'_id': {'end station id': 3237}, 'agg_count': 1}
# {'_id': {'end station id': 275}, 'agg_count': 1}
# {'_id': {'end station id': 239}, 'agg_count': 1}
# {'_id': {'end station id': 420}, 'agg_count': 1}
# {'_id': {'end station id': 3155}, 'agg_count': 1}
# {'_id': {'end station id': 3224}, 'agg_count': 1}
# {'_id': {'end station id': 335}, 'agg_count': 1}
# {'_id': {'end station id': 463}, 'agg_count': 1}
# {'_id': {'end station id': 3229}, 'agg_count': 1}
# {'_id': {'end station id': 281}, 'agg_count': 1}
# {'_id': {'end station id': 223}, 'agg_count': 1}
# {'_id': {'end station id': 244}, 'agg_count': 1}
# {'_id': {'end station id': 3122}, 'agg_count': 1}
# {'_id': {'end station id': 434}, 'agg_count': 1}
# {'_id': {'end station id': 300}, 'agg_count': 1}
# {'_id': {'end station id': 522}, 'agg_count': 1}
# {'_id': {'end station id': 243}, 'agg_count': 1}
# {'_id': {'end station id': 342}, 'agg_count': 1}
# {'_id': {'end station id': 3017}, 'agg_count': 1}
# {'_id': {'end station id': 533}, 'agg_count': 1}
# {'_id': {'end station id': 242}, 'agg_count': 1}
# {'_id': {'end station id': 385}, 'agg_count': 1}
# {'_id': {'end station id': 492}, 'agg_count': 1}
# {'_id': {'end station id': 298}, 'agg_count': 1}
# {'_id': {'end station id': 379}, 'agg_count': 1}
# {'_id': {'end station id': 359}, 'agg_count': 1}
# {'_id': {'end station id': 325}, 'agg_count': 1}
# {'_id': {'end station id': 373}, 'agg_count': 1}
# {'_id': {'end station id': 3166}, 'agg_count': 1}
# {'_id': {'end station id': 3059}, 'agg_count': 1}
# {'_id': {'end station id': 3154}, 'agg_count': 1}
# {'_id': {'end station id': 484}, 'agg_count': 1}
# {'_id': {'end station id': 515}, 'agg_count': 1}
# {'_id': {'end station id': 282}, 'agg_count': 1}
# {'_id': {'end station id': 436}, 'agg_count': 1}
